# %%
import numpy as np
import pandas as pd

# %%
架构 =  pd.read_excel('组织架构导入表.xlsx', sheet_name='Sheet1')

# %%
架构.fillna('', inplace=True)
架构.columns = ['main', 'position', 'name', 'type']

# %%
with open('架构.json', 'w', encoding='utf-8') as file:
    架构.to_json(file, orient='records', force_ascii=False)

# %%
架构
# Out:
#    main position   name         type
# 0    BT       北京    财务部         职能部门
# 1    BT       北京    总裁办         职能部门
# 2    BT       北京  人事行政部         职能部门
# 3    BT       北京    发行部            -
# 4    BT       北京  中台研发部         中台部门
# 5    BT       北京    运营部         运营部门
# 6    BT       北京  市场投放组         市场部门
# 7    BT       北京  市场素材组         市场部门
# 8    BT       北京  中台美术部         中台部门
# 9    BT       北京   A1项目  研发部门-A直接项目组
# 10   BT       北京   A2项目  研发部门-A直接项目组
# 11   BT       北京   A3项目  研发部门-A直接项目组
# 12   BT       北京  A项目美术         研发部门
# 13   BT       北京  A项目程序         研发部门
# 14   BT       北京  中台测试部         中台部门
# 15   BT       北京   H1项目  研发部门-H直接项目组
# 16   BT       北京   H2项目  研发部门-H直接项目组
# 17   CT       成都  人事行政部         职能部门
# 18   CT       成都    运营部         运营部门
# 19   CT       成都  市场素材组         市场部门
# 20   CT       成都  美术中台部         中台部门
# 21   CT       成都   T1项目  研发部门-T直接项目组
# 22   CT       成都   T2项目  研发部门-T直接项目组
# 23   CT       成都  T项目美术         研发部门
# 24   CT       成都  研发中台部         中台部门
